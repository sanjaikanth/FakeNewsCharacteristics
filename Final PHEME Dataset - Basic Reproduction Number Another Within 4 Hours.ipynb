# %% [markdown]
# Basic Reproduction Number is the average number of secondary infections that can be generated by a single infected individual Within time range

# %%
"""
Python 3 function to convert rumour annotations into True, False, Unverified
"""

def convert_annotations(annotation, string = True):
    if 'misinformation' in annotation.keys() and 'true'in annotation.keys():
        if int(annotation['misinformation'])==0 and int(annotation['true'])==0:
            if string:
                label = "unverified"
            else:
                label = 2
        elif int(annotation['misinformation'])==0 and int(annotation['true'])==1 :
            if string:
                label = "true"
            else:
                label = 1
        elif int(annotation['misinformation'])==1 and int(annotation['true'])==0 :
            if string:
                label = "false"
            else:
                label = 0
        elif int(annotation['misinformation'])==1 and int(annotation['true'])==1:
            print ("OMG! They both are 1!")
            print(annotation['misinformation'])
            print(annotation['true'])
            label = None
            
    elif 'misinformation' in annotation.keys() and 'true' not in annotation.keys():
        # all instances have misinfo label but don't have true label
        if int(annotation['misinformation'])==0:
            if string:
                label = "unverified"
            else:
                label = 2
        elif int(annotation['misinformation'])==1:
            if string:
                label = "false"
            else:
                label = 0
                
    elif 'true' in annotation.keys() and 'misinformation' not in annotation.keys():
        #print ('Has true not misinformation')
        label = None
    else:
        #print('No annotations')
        label = None
           
    return label

# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import Markdown as md
import json


tweetSet='twitter16'
# Define the path to your text file
#file_path = './Data/twitter16/label.txt'
file_path = './Data/PHEME_veracity/all-rnr-annotated-threads/gurlitt-all-rnr-threads/rumours/536826643122503680/annotation.json'


# Open and read the JSON file
with open(file_path, 'r') as file:
    data = json.load(file)

# Create a dictionary (hashtable) and add the key-value pairs
my_dict = {}
for key, value in data.items():
    my_dict[key] = value
    
print(my_dict['is_rumour'])
my_dict.keys
# # Initialize empty lists to store the data
# labels = []
# values = []

# # Read the file line by line and extract the data
# with open(file_path, 'r') as file:
#     for line in file:
#         line = line.strip()  # Remove any leading/trailing whitespace
#         label, value = line.split(':')  # Split the line into label and value
#         labels.append(label)
#         values.append(int(value))  # Convert the value to an integer
# Out:
# rumour
# <function dict.keys>

# %%
convert_annotations(my_dict)
# Out:
# 'true'

# %%
import os
# Create a DataFrame from the lists
df = pd.DataFrame(columns=['TweetID', 'IsRumour', 'IsTrue','Path','CreatedAt'])
df
count=0
Incidentdirectory = './Data/PHEME_veracity/all-rnr-annotated-threads/'
for subdirectoryIncident in os.listdir(Incidentdirectory):
    subdirectoryIncident_path = os.path.join(Incidentdirectory, subdirectoryIncident)
    if os.path.isdir(subdirectoryIncident_path):
        rmourOrnonrumour=['rumours','non-rumours']
        for rumourLabel in rmourOrnonrumour:
            directory =subdirectoryIncident_path+'/'+rumourLabel
            #directory = './Data/PHEME_veracity/all-rnr-annotated-threads/ottawashooting-all-rnr-threads/'+rumourLabel
            for subdirectory in os.listdir(directory):
                    subdirectory_path = os.path.join(directory, subdirectory)
                    if os.path.isdir(subdirectory_path):
                        count=count+1
                        #print("Subdirectory: ",count, subdirectory_path )
                        # Open and read the JSON file
                        file_path=subdirectory_path+'/annotation.json'
                        with open(file_path, 'r') as file:
                            data = json.load(file)
                            my_dict = {}
                            for key, value in data.items():
                                my_dict[key] = value
                            
#                             file_path_sourceTweet=subdirectory_path+'/source-tweets/'+subdirectory+'.json'
#                             with open(file_path_sourceTweet, 'r') as fileSource:
#                                 data_Source = json.load(fileSource)
#                             # Extract the value of the 'created_at' field
#                             created_at_str  = data_Source['created_at']


                            #print(convert_annotations(my_dict))
                            # Create a dictionary with the data for the new row
                            new_row_data = {
                                'TweetID': subdirectory,
                                'IsRumour':  my_dict['is_rumour'],
                                'IsTrue':convert_annotations(my_dict) ,#'true' if my_dict['is_rumour']=='nonrumour' else convert_annotations(my_dict) ,
                                'Path':subdirectory_path
                            }
                            # Convert the dictionary to a DataFrame
                            new_row_df = pd.DataFrame(new_row_data, index=[0])
                            # Concatenate the new row DataFrame with the original DataFrame
                            df = pd.concat([df, new_row_df], ignore_index=True)
df
# Out:
#                  TweetID   IsRumour IsTrue  \
# 0     552783238415265792     rumour   true
# 1     552783667052167168     rumour   true
# 2     552783745565347840     rumour   true
# 3     552784168849907712     rumour   true
# 4     552784526955806720     rumour   true
# ...                  ...        ...    ...
# 6420  544521260840267776  nonrumour   None
# 6421  544521433473634304  nonrumour   None
# 6422  544521788777304064  nonrumour   None
# 6423  544521880661950464  nonrumour   None
# 6424  544521948924248066  nonrumour   None
#
#                                                    Path CreatedAt
# 0     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 1     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 2     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 3     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 4     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# ...                                                 ...       ...
# 6420  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 6421  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 6422  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 6423  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 6424  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
#
# [6425 rows x 5 columns]

# %%
# Get the value counts of 'IsTrue'
value_counts = df['IsTrue'].value_counts()

print("Value Counts of 'IsTrue':")
print(value_counts)
# Out:
# Value Counts of 'IsTrue':
# true          1067
# unverified     697
# false          638
# Name: IsTrue, dtype: int64

# %%
df[df['IsTrue'].isin(['true','false'])]['IsTrue'].unique()
df[df['IsTrue'].isin(['true','false'])]['IsTrue'].value_counts()
df=df[df['IsTrue'].isin(['true','false'])]
# Convert 'IsTrue' column to boolean
#df['IsTrue'] = df['IsTrue'].map({'true': True, 'false': False})
df = df.reset_index(drop=True)
df
# Out:
#                  TweetID IsRumour IsTrue  \
# 0     552783238415265792   rumour   true
# 1     552783667052167168   rumour   true
# 2     552783745565347840   rumour   true
# 3     552784168849907712   rumour   true
# 4     552784526955806720   rumour   true
# ...                  ...      ...    ...
# 1700  544520273718812672   rumour   true
# 1701  544520654431981568   rumour   true
# 1702  544520932405284864   rumour   true
# 1703  544521141335764992   rumour   true
# 1704  544521166543548416   rumour   true
#
#                                                    Path CreatedAt
# 0     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 1     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 2     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 3     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 4     ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# ...                                                 ...       ...
# 1700  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 1701  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 1702  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 1703  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
# 1704  ./Data/PHEME_veracity/all-rnr-annotated-thread...       NaN
#
# [1705 rows x 5 columns]

# %%
df.iloc[0]['Path']
# Out:
# './Data/PHEME_veracity/all-rnr-annotated-threads/charliehebdo-all-rnr-threads/rumours\\552783238415265792'

# %%
from datetime import datetime

# # Iterate through the DataFrame and add Created At
for index, row in df.iterrows(): # df[:1000].iterrows(): 
    #fileName=df.iloc[index]['Path']+'/structure.json'
    file_path_sourceTweet=df.iloc[index]['Path']+'/source-tweets/'+df.iloc[index]['TweetID']+'.json'
    with open(file_path_sourceTweet, 'r') as fileSource:
        data_Source = json.load(fileSource)
    # Extract the value of the 'created_at' field
    created_at_str  = data_Source['created_at']
    # Convert the string to a datetime object
    created_at_datetime = datetime.strptime(created_at_str, '%a %b %d %H:%M:%S +0000 %Y')
    df.iloc[index]['CreatedAt']=created_at_datetime
df
# Out:
#                  TweetID IsRumour IsTrue  \
# 0     552783238415265792   rumour   true
# 1     552783667052167168   rumour   true
# 2     552783745565347840   rumour   true
# 3     552784168849907712   rumour   true
# 4     552784526955806720   rumour   true
# ...                  ...      ...    ...
# 1700  544520273718812672   rumour   true
# 1701  544520654431981568   rumour   true
# 1702  544520932405284864   rumour   true
# 1703  544521141335764992   rumour   true
# 1704  544521166543548416   rumour   true
#
#                                                    Path            CreatedAt
# 0     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:06:08
# 1     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:07:51
# 2     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:08:09
# 3     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:09:50
# 4     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:11:16
# ...                                                 ...                  ...
# 1700  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:52:04
# 1701  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:53:35
# 1702  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:54:41
# 1703  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:55:31
# 1704  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:55:37
#
# [1705 rows x 5 columns]

# %%
df['NumberOfRetweets']=0
df['TotalDiffusionTime']=''

df
# Out:
#                  TweetID IsRumour IsTrue  \
# 0     552783238415265792   rumour   true
# 1     552783667052167168   rumour   true
# 2     552783745565347840   rumour   true
# 3     552784168849907712   rumour   true
# 4     552784526955806720   rumour   true
# ...                  ...      ...    ...
# 1700  544520273718812672   rumour   true
# 1701  544520654431981568   rumour   true
# 1702  544520932405284864   rumour   true
# 1703  544521141335764992   rumour   true
# 1704  544521166543548416   rumour   true
#
#                                                    Path            CreatedAt  \
# 0     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:06:08
# 1     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:07:51
# 2     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:08:09
# 3     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:09:50
# 4     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:11:16
# ...                                                 ...                  ...
# 1700  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:52:04
# 1701  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:53:35
# 1702  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:54:41
# 1703  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:55:31
# 1704  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:55:37
#
#       NumberOfRetweets TotalDiffusionTime
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0
# ...                ...                ...
# 1700                 0
# 1701                 0
# 1702                 0
# 1703                 0
# 1704                 0
#
# [1705 rows x 7 columns]

# %%
from datetime import datetime, timedelta
try:
    check=0
    for index, row in df.iterrows(): # df[:1000].iterrows(): 
        #fileName=df.iloc[index]['Path']+'/structure.json'
        Directory_path_ReactionTweet=df.iloc[index]['Path']+'/reactions/' #+df.iloc[index]['TweetID']+'.json'
        Source_CreatedTime= df.iloc[index]['CreatedAt']# datetime.strptime(df.iloc[index]['CreatedAt'], '%a %b %d %H:%M:%S +0000 %Y') 
        # Initialize A with the minimum datetime value
        DiffusionTime = datetime.min
        Counter=0
        for subdirectory in os.listdir(Directory_path_ReactionTweet):
            subdirectory_path = os.path.join(Directory_path_ReactionTweet, subdirectory)

            #if os.path.isdir(subdirectory_path):
            if not subdirectory.startswith("._") and subdirectory.endswith(".json"):
                #print(subdirectory_path)
                with open(subdirectory_path, 'r') as fileReactions:
                    data_Reactions = json.load(fileReactions)
                # Extract the value of the 'created_at' field
                tweet_at_str  = data_Reactions['created_at']
                # Convert the string to a datetime object
                tweet_at_datetime = datetime.strptime(tweet_at_str, '%a %b %d %H:%M:%S +0000 %Y')
                
                #tweetTime=datetime.strptime(created_at_str, '%a %b %d %H:%M:%S +0000 %Y')
                
                time_difference = abs(tweet_at_datetime - Source_CreatedTime)
                
#                 check=check+1
#                 if check<1000:
#                     print (tweet_at_datetime,Source_CreatedTime)
#                     print(time_difference)
#                     print(time_difference < timedelta(hours=4))
#                     print(Counter)
                if time_difference < timedelta(hours=1):
                    Counter=Counter+1
        #df.iloc[index]['NumberOfRetweets']=Counter
        df.loc[index, 'NumberOfRetweets'] = Counter

#                 # Compare and update A if B is greater
#                 if created_at_datetime > DiffusionTime:
#                     DiffusionTime = created_at_datetime
#                     df.iloc[index]['TotalDiffusionTime']=DiffusionTime
        
except json.JSONDecodeError as e:
    print(f"JSON decoding error: {e}")
    print("JSON data:", subdirectory_path)
df
# Out:
#                  TweetID IsRumour IsTrue  \
# 0     552783238415265792   rumour   true
# 1     552783667052167168   rumour   true
# 2     552783745565347840   rumour   true
# 3     552784168849907712   rumour   true
# 4     552784526955806720   rumour   true
# ...                  ...      ...    ...
# 1700  544520273718812672   rumour   true
# 1701  544520654431981568   rumour   true
# 1702  544520932405284864   rumour   true
# 1703  544521141335764992   rumour   true
# 1704  544521166543548416   rumour   true
#
#                                                    Path            CreatedAt  \
# 0     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:06:08
# 1     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:07:51
# 2     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:08:09
# 3     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:09:50
# 4     ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:11:16
# ...                                                 ...                  ...
# 1700  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:52:04
# 1701  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:53:35
# 1702  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:54:41
# 1703  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:55:31
# 1704  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 15:55:37
#
#       NumberOfRetweets TotalDiffusionTime
# 0                    4
# 1                    6
# 2                    4
# 3                   12
# 4                   14
# ...                ...                ...
# 1700                17
# 1701                 0
# 1702                16
# 1703                12
# 1704                19
#
# [1705 rows x 7 columns]

# %%
df = df.sort_values(by='NumberOfRetweets', ascending=False) 
df = df.reset_index(drop=True)
df.head(55)
# Out:
#                TweetID IsRumour IsTrue  \
# 0   552793552376569857   rumour   true
# 1   552993818816299008   rumour  false
# 2   552805488631758849   rumour   true
# 3   525033778637721600   rumour   true
# 4   552795773180858368   rumour   true
# 5   544430771688439808   rumour   true
# 6   544329935943237632   rumour   true
# 7   552985855854661633   rumour   true
# 8   544287922166726657   rumour  false
# 9   524964948683005952   rumour  false
# 10  525029016001318913   rumour   true
# 11  544307028815253504   rumour  false
# 12  552788886355996672   rumour   true
# 13  552821287933202435   rumour   true
# 14  544445364322197504   rumour   true
# 15  524984773211860994   rumour   true
# 16  544454229960974336   rumour   true
# 17  580320745974288384   rumour   true
# 18  552806309540528128   rumour  false
# 19  552792271243210754   rumour   true
# 20  544321103875694593   rumour   true
# 21  544277728930062336   rumour  false
# 22  553587013409325058   rumour   true
# 23  544384041391517697   rumour   true
# 24  580325799078793216   rumour   true
# 25  553557308937363458   rumour  false
# 26  552813461953323008   rumour   true
# 27  524956129017995264   rumour  false
# 28  525031558949134336   rumour   true
# 29  552837132491186179   rumour  false
# 30  544288661253398528   rumour  false
# 31  525017500061536258   rumour   true
# 32  544274934835707905   rumour   true
# 33  580319651399385088   rumour   true
# 34  544274544174071809   rumour  false
# 35  553501773517033472   rumour   true
# 36  544277526248304640   rumour   true
# 37  524946921547628545   rumour   true
# 38  525028171549523971   rumour   true
# 39  552802606696136705   rumour   true
# 40  500360244187635712   rumour   true
# 41  544307776135364608   rumour  false
# 42  580352273001410560   rumour  false
# 43  524949339131904000   rumour   true
# 44  553587672137334785   rumour   true
# 45  544315864397258752   rumour   true
# 46  552788945017516032   rumour   true
# 47  524936872666353664   rumour   true
# 48  524969483317026816   rumour   true
# 49  524925124303396864   rumour   true
# 50  544489340584222720   rumour   true
# 51  580321948070240256   rumour   true
# 52  500371231183745025   rumour   true
# 53  581252958446329857   rumour  false
# 54  524941720249978880   rumour   true
#
#                                                  Path            CreatedAt  \
# 0   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:47:07
# 1   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-08 01:02:55
# 2   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 12:34:33
# 3   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 21:19:42
# 4   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:55:57
# 5   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 09:56:25
# 6   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 03:15:44
# 7   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-08 00:31:16
# 8   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 00:28:47
# 9   ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 16:46:11
# 10  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 21:00:46
# 11  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 01:44:43
# 12  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:28:35
# 13  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 13:37:20
# 14  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 10:54:24
# 15  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 18:04:58
# 16  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 11:29:38
# 17  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-03-24 10:50:22
# 18  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 12:37:49
# 19  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:42:02
# 20  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 02:40:38
# 21  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-14 23:48:17
# 22  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-09 16:20:03
# 23  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 06:50:44
# 24  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-03-24 11:10:27
# 25  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-09 14:22:01
# 26  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 13:06:14
# 27  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 16:11:09
# 28  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 21:10:52
# 29  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 14:40:18
# 30  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 00:31:43
# 31  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 20:15:01
# 32  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-14 23:37:11
# 33  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-03-24 10:46:01
# 34  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-14 23:35:38
# 35  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-09 10:41:21
# 36  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-14 23:47:29
# 37  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 15:34:33
# 38  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 20:57:25
# 39  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 12:23:06
# 40  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-08-15 19:15:53
# 41  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 01:47:41
# 42  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-03-24 12:55:38
# 43  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 15:44:10
# 44  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-09 16:22:40
# 45  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 02:19:49
# 46  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-01-07 11:28:49
# 47  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 14:54:37
# 48  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 17:04:12
# 49  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 14:07:56
# 50  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-12-15 13:49:09
# 51  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-03-24 10:55:08
# 52  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-08-15 19:59:32
# 53  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2015-03-27 00:34:39
# 54  ./Data/PHEME_veracity/all-rnr-annotated-thread...  2014-10-22 15:13:53
#
#     NumberOfRetweets TotalDiffusionTime
# 0                 89
# 1                 85
# 2                 82
# 3                 80
# 4                 73
# 5                 71
# 6                 54
# 7                 48
# 8                 48
# 9                 43
# 10                43
# 11                42
# 12                41
# 13                39
# 14                39
# 15                37
# 16                35
# 17                34
# 18                33
# 19                33
# 20                33
# 21                33
# 22                33
# 23                32
# 24                32
# 25                31
# 26                31
# 27                31
# 28                31
# 29                31
# 30                30
# 31                30
# 32                29
# 33                29
# 34                29
# 35                29
# 36                29
# 37                29
# 38                29
# 39                29
# 40                28
# 41                28
# 42                27
# 43                27
# 44                27
# 45                27
# 46                26
# 47                26
# 48                26
# 49                26
# 50                26
# 51                26
# 52                26
# 53                26
# 54                26

# %%
average_counts = df.groupby('IsTrue')['NumberOfRetweets'].mean()
average_counts
# Out:
# IsTrue
# false     6.700627
# true     10.050609
# Name: NumberOfRetweets, dtype: float64
